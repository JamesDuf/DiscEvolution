# %% [markdown]
# # Background Stuff

# %%
#Imports 
import astropy.units as u
import astropy.constants as const
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

from DiscEvolution.grid import Grid
from DiscEvolution.star import SimpleStar
#from DiscEvolution.eos import LocallyIsothermalEOS  
from DiscEvolution.eos import SimpleDiscEOS
from DiscEvolution.eos import IrradiatedEOS  
#from DiscEvolution.disc import AccretionDisc
#from DiscEvolution.viscous_evolution import ViscousEvolutionFV
from DiscEvolution.driver import PlanetDiscDriver
from DiscEvolution.io import Event_Controller
from DiscEvolution.dust import DustGrowthTwoPop, SingleFluidDrift
from DiscEvolution.viscous_evolution import HybridWindModel
from DiscEvolution.opacity import Zhu2012
from DiscEvolution.constants import yr as yr_code  # DiscEvolution uses code units: 1 year = 2π code time units
from DiscEvolution.internal_photo import ConstantInternalPhotoevap
from DiscEvolution.chemistry import SimpleCOAtomAbund, EquilibriumCOChemOberg
from DiscEvolution import planet_formation as pf

# Increase resolution (DPI) for better quality
plt.rcParams['figure.dpi'] = 300

# %%
#Initialized but value given in next cell
M_disk_0 = None
Rc = None
R_in = None
Mdot_0 = None
Mstar = None
Rstar = None
mu = None
# LBP surface density profile with gamma = 1: Sigma(r) = (M_disk / (2*pi*Rc*r)) * exp(-r/Rc)
def Sigma_LBP_1(r) -> float:
    val = (M_disk_0)/(2* np.pi * Rc * r) * np.exp((-1*r)/(Rc))
    if (val.cgs.unit != (u.g / (u.cm)**2)):
        print("Sigma_1 error")
        return 0
    return val.cgs

def Temperature(r) -> float:
    T_0 = 150 * u.K 
    val  = T_0 * (r / (1.0 * u.AU))**(-1/2)
    if val.cgs.unit != u.K:
        print('Temperature error')
        return 0
    return val.cgs

def Omega(r) -> float:
    val = np.sqrt((const.G*Mstar)/(r**3))
    if (val.cgs.unit != (1 / u.s)): 
        print("Omega error")
        return 0
    return val.cgs

def c_s(r) -> float:
    val = np.sqrt((const.k_B*Temperature(r))/(mu*const.m_p))
    if (val.cgs.unit != (u.cm / u.s)): 
        print("c_s error")
        return 0
    return val.cgs

def H(r) -> float: 
    val = c_s(r)/Omega(r)
    if val.cgs.unit != (u.cm):
        print("H error")
        return 0
    return val.cgs

#Given Mdisk, Mdot(0), Rc -> Calculate alpha and Sigma0
def calculateAlpha() -> float:
    Rin_cgs = (R_in * u.AU).to(u.cm)               #cm
    Mdot_cgs = Mdot_0.to(u.g / u.s).value  # g/s
    M_disk_cgs = M_disk_0.cgs.value         #g
    cs_val = c_s(Rin_cgs).value                   # cm/s
    omega = Omega(Rin_cgs).value                   # 1/s
    Rc_cgs = Rc.cgs.value               #cm
    alpha = Mdot_cgs*((2*Rin_cgs.value*omega)/3) * (Rc_cgs/((cs_val**2) * M_disk_cgs))
    return alpha

# %% [markdown]
# # Parameters

# %%
t_initial = 0.1 * u.Myr
t_initial_yr = t_initial.to(u.yr).value 
t_initial_code = t_initial_yr * yr_code  #Convert to code units

t_final = 2.0 * u.Myr
t_final_yr = t_final.to(u.yr).value 
t_final_code = t_final_yr * yr_code  #Convert to code units

snapshot_offsets_yr = np.array([0.9e6, 1.4e6, 1.9e6]) #times to save snapshots at, t + offset = t_snap

M_disk_0 = 0.32 * u.solMass #High-mass
#Mdot_0 = 5E-8 * u.solMass / u.yr  #TODO
Rc = 91.0 * u.AU #where disc starts fading out at 0.1 Myr in order to be at 120 AU at 1Myr
Mstar = 1.2 * u.solMass
Rstar = 3.0 * u.solRad
Tstar = 4395.0 * u.K
mu = 2.33

# %%
alpha_eff = 1e-3 # Drives the gas disk evolution
alpha_dead = 1e-5
alpha_active = alpha_eff - alpha_dead

#Deadzone parameters
dz_width_scaling = 0.1
R_dz_initial = 2.0e1 * u.AU
R_dz_min = 1.0 * u.AU

print(f"alpha_active: {alpha_active:.2e}")
print(f"alpha_dead: {alpha_dead:.2e}")
print(f"Transition width: {dz_width_scaling:.1f} * H")
print(f"Initial Deadzone Radius: {R_dz_initial:.1f}")
print(f"Mininum Deadzone Radius: {R_dz_min:.1f}")

def compute_R_dz(t_yr, R_dz_initial_AU, R_dz_min_AU, t_start_yr, t_final_yr) -> float: 
    """
    Moves Rdz linearly from initial to min over the disc lifetime.
    """

    disc_lifetime_yr = t_final_yr - t_start_yr
    distance = R_dz_initial_AU.value - R_dz_min_AU.value 
    velocity = distance / disc_lifetime_yr #Au/yr 
    t_rel = max(0.0, t_yr - t_start_yr)

    return max(R_dz_initial_AU.value - (velocity * t_rel), R_dz_min_AU.value) 

def compute_alpha_turb_array(R, H, R_dz, alpha_dead, alpha_active, width_factor=1.0):
    """
    Creates a smooth alpha_turb array that transitions at R_dz.
    Transitions in log-space to ensure smooth orders of magnitude.
    
    Args:
        R: radial grid (array, AU)
        H: scale height (array, AU)
        R_dz: dead zone radius (scalar, AU)
        alpha_dead: turbulent alpha in dead zone
        alpha_active: turbulent alpha in active zone
        width_factor: transition width in units of H at R_dz
    """

    log_a_dead = np.log10(alpha_dead)
    log_a_active = np.log10(alpha_active)

    # Find the exact scale height (H) at the deadzone boundary
    H_at_rdz = np.interp(R_dz, R, H)
    
    # Tanh transition: 0 in dead zone, 1 in active zone
    transition = 0.5 * (1.0 + np.tanh((R - R_dz) / (width_factor * H_at_rdz)))
    
    # Blend in log space
    log_alpha_array = log_a_dead + transition * (log_a_active - log_a_dead)
    
    return 10**log_alpha_array
# Out:
# alpha_active: 9.90e-04
# alpha_dead: 1.00e-05
# Transition width: 0.1 * H
# Initial Deadzone Radius: 20.0 AU
# Mininum Deadzone Radius: 1.0 AU

# %%
# 1) Create grid
R_in = 0.1 #AU
R_out = 120.0  # AU
Ncells = 500
grid = Grid(R_in, R_out, Ncells, spacing='natural')

# %%
# 2) Create star
star = SimpleStar(M = Mstar.value ,R = Rstar.value, T_eff = Tstar.value, age = t_initial_yr)  #Msun, Rsun, K, yr

# %%
# 3) Create EOS (start with scalar alpha_active, set the array after first update)
#eos = IrradiatedEOS(
#    star,
#    alpha_t=alpha_active,   # Scalar placeholder — will be overridden with array later
#    alpha_tot=alpha_eff,    # Constant total alpha → psi derived automatically
#    Tc=10,                  # External/nebular temperature floor (K)
#    Tmax=1500,              # Maximum temperature cap (K)
#    mu=mu,
#    gamma=1.0,
#    accrete=True,           # Include viscous heating from accretion
#    kappa=Zhu2012,
#    e_rad= 0.9
#)
# psi array is created and attached to eos inside alpha_array setter! 


eos = SimpleDiscEOS(star, alpha_t=alpha_active, alpha_tot=alpha_eff, e_rad=0.9)

eos.set_grid(grid)

# %%
# 4) Initial EOS solve → gives us H(R), then compute alpha_turb array
R_centers = grid.Rc  # AU
Sigma_initial = np.array([Sigma_LBP_1(r * u.AU).value for r in R_centers])

# First pass: solve T structure with scalar alpha to get H(R)
eos.update(0, Sigma_initial)

# Now we have eos.H → build the spatially varying alpha_turb
R_dz_0 = compute_R_dz(t_initial_yr, R_dz_initial, R_dz_min, t_initial_yr, t_final_yr)
alpha_turb_array = compute_alpha_turb_array(grid.Rc, eos.H, R_dz_0, alpha_dead, alpha_active, dz_width_scaling)

# Set the array alpha → psi auto-updates via the setter
eos.alpha_t = alpha_turb_array

# Second pass: re-solve T with the actual spatially varying alpha
eos.update(0, Sigma_initial)

print(f"psi range: [{eos.psi.min():.1f}, {eos.psi.max():.1f}]")
print(f"alpha_turb range: [{eos.alpha_t.min():.2e}, {eos.alpha_t.max():.2e}]")
# Out:
# psi range: [0.0, 99.0]
# alpha_turb range: [1.00e-05, 9.90e-04]
# /Users/james/Documents/GitHub/DiscEvolution/DiscEvolution/eos.py:236: RuntimeWarning: divide by zero encountered in divide
#   return 1. / Pr_1

# %%
# 5) Create the disc with dust
disc = DustGrowthTwoPop(
    grid, 
    star, 
    eos, 
    eps=0.01,              # Initial dust-to-gas ratio
    Sigma=Sigma_initial,
    feedback=True,         # Dust affects gas dynamics
    f_ice=1,             # Ice fraction (affects fragmentation)
    uf_0=100,             # Fragmentation velocity for dry grains (cm/s)
    uf_ice=1000,           # Fragmentation velocity for icy grains (cm/s)
    thresh=0.5             # Threshold for ice effects
)

disc._planetesimal = False #Turn off planetessimals for now
disc.update(0.0) #This is to have the pebble size and stokes number correct at t=0

# %%
# 6) Set up viscous evolution — psi is now an array from the EOS
visc_evol = HybridWindModel(psi_DW=eos.psi, lambda_DW=3, tol=0.5, boundary='power_law', in_bound='Mdot')
disc._gas = visc_evol

# %%
# 6.2) Add Chemistry
# Create chemistry solver
chem_model = EquilibriumCOChemOberg(fix_ratios=False, a=1e-5)

# Set solar abundances
X_solar = SimpleCOAtomAbund(disc.Ncells)
X_solar.set_solar_abundances()

# Iterate to convergence (ice fraction changes dust-to-gas ratio)
for i in range(10):
    chem = chem_model.equilibrium_chem(
        disc.T, 
        disc.midplane_gas_density,
        disc.dust_frac.sum(0), 
        X_solar
    )
    disc.initialize_dust_density(chem.ice.total_abund)

# Attach to disc
disc.chem = chem
disc.update_ices(disc.chem.ice)

drift = SingleFluidDrift(diffusion=None, settling=True)

driver = PlanetDiscDriver(
    disc, 
    gas=visc_evol, 
    dust=drift,
    chemistry=chem_model,  #Driver will handle updating chemistry for gas and ices
    t0=t_initial_code
)

# %%
# Compute trap radii (self-contained, SimpleDiscEOS version)
_R = disc.R
_T = disc.T
_Sigma = disc.Sigma_G

# Irradiation temperature: T_irr = Tirr0 * R^(-3/7)
_T_irr = eos._Tirr0 * _R**(-3/7.)

# Viscous temperature: T_vis = Tnu * sqrt((1+psi)*e_rad) * Sigma * R^(-0.75)
_T_visc = (eos._Tnu * np.sqrt((1 + eos._psi) * eos._e_rad)
           * _Sigma * _R**-0.75)

# --- Trap radii ---
# 1) Heat transition: where T_irr ≈ T_visc
cross_idx = np.argmin(np.abs(_T_irr - _T_visc))
R_ht = _R[cross_idx]

# 2) Ice line: where T crosses 170 K
ice_idx = np.argmin(np.abs(_T - 170))
R_ice = _R[ice_idx]

# 3) Dead zone edge (current time)
R_dz_now = compute_R_dz(driver.t / yr_code, R_dz_initial, R_dz_min, t_initial_yr, t_final_yr)

# %%
# 7) Setup evolution 
# Check timestep size
run_start_yr = t_initial_yr
run_end_yr = t_final_yr
run_duration_yr = run_end_yr - run_start_yr

dt_max = visc_evol.max_timestep(disc) / yr_code
print(f"dt_max = {dt_max:.1f} years")
print(f"Estimated steps: {run_duration_yr/dt_max:.0f}")

# Output times (absolute years, matching driver.t timeline)
output_times_yr = np.linspace(run_start_yr, run_end_yr, 11)
output_times_code = output_times_yr * yr_code

# Snapshot offsets from t_initial
#snapshot_offsets_yr = np.array([0.1e6, 0.25e6, 0.4e6,])    #Now is at the top with other params
snapshot_times_yr = run_start_yr + snapshot_offsets_yr
snapshot_times_code = snapshot_times_yr * yr_code

io = Event_Controller(save=output_times_code, snapshot=snapshot_times_code)

history = {'t_yr': [], 'Mtot': [], 'Rout': [], 'dt_yr': [], 'Rc': []}
snapshots = {'t_yr': [], 'Sigma_G': [], 'Sigma_D': [], 'dust_frac': [], 'St': [], 'grain_size': [], 'T': [], 'P': [], 'chem_ice': [], 'chem_gas': [], 'mid_gas_dens': [], 'rdz': [], 'alpha': [], 'H': [], 'rht': [], 'ril': []}

# t = t_initial history
dt_current = visc_evol.max_timestep(disc)
history['t_yr'].append(driver.t / yr_code)
history['Mtot'].append(disc.Mtot() * u.g.to(u.solMass))
history['Rout'].append(disc.Rout())
history['dt_yr'].append(dt_current / yr_code)
history['Rc'].append(disc.RC())

# t = t_initial snapshot
snapshots['t_yr'].append(driver.t / yr_code)
snapshots['Sigma_G'].append(disc.Sigma_G.copy())
snapshots['Sigma_D'].append(disc.Sigma_D.sum(axis=0).copy()) #Total dust Sigma, pebbles + grains
snapshots['dust_frac'].append(disc.dust_frac.sum(axis=0).copy()) #Total dust to gas ratio
snapshots['St'].append(disc.Stokes()[1].copy())  #Pebbles not small grains
snapshots['grain_size'].append(disc.grain_size[1].copy()) #Pebbles not small grains
snapshots['T'].append(disc.T.copy()) #Temp
snapshots['P'].append(disc.P.copy()) #Pressure
snapshots['chem_ice'].append(disc.chem.ice.data.copy())
snapshots['chem_gas'].append(disc.chem.gas.data.copy())
snapshots['mid_gas_dens'].append(disc.midplane_gas_density.copy())
snapshots['rdz'].append(R_dz_initial.value)
snapshots['alpha'].append(alpha_turb_array.copy())
snapshots['H'].append(disc.H.copy())
snapshots['rht'].append()
snapshots['ril'].append()
# Out:
# dt_max = 25.3 years
# Estimated steps: 75093

# %%
# 7.2) Setup torque maps

#Create M-R diagram space
mass_array = np.logspace(-2,3,Ncells) #Mearth required by compute_torque function
radius_array = disc.R #AU
R_grid, M_grid = np.meshgrid(radius_array, mass_array) #2D grid from two 1D arrays

#Storage array
torque_maps = {
    't_yr': [],
    'maps': []
}

#Initial Torque map
TypeI = pf.TypeIMigration(disc) #Creates a Type I migration object from the disc object
Torque_map = np.zeros_like(R_grid) #initialize 2D grid with all values zero 

#Compute Torques
for i, Mp in enumerate(mass_array):
    #Pass Mp as an array of the same shape as radius_array
    Mp_array = np.ones_like(radius_array) * Mp #entire row with said mass value
    #Compute the total torque for said mass at each R 
    Torque_map[i, :] = TypeI.compute_torque_raw(radius_array, Mp_array)

torque_maps['t_yr'].append(driver.t / yr_code)
torque_maps['maps'].append(Torque_map)

# %%
#Plot the intial values
# Plot evolution results with dust properties and chemistry
fig, axes = plt.subplots(3, 3, figsize=(15, 15))
lw = 1.5

# Get chemical species names and find indices
try:
    chem_species = disc.chem.ice.names
    idx_CO = chem_species.index('CO') if 'CO' in chem_species else None
    idx_H2O = chem_species.index('H2O') if 'H2O' in chem_species else None
    idx_CH4 = chem_species.index('CH4') if 'CH4' in chem_species else None
except (AttributeError, ValueError):
    idx_CO = idx_H2O = idx_CH4 = None

# 1. Surface density: Gas and Dust
ax = axes[0, 0]

ax.loglog(disc.R, snapshots['Sigma_G'][0], linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)
ax.loglog(disc.R, snapshots['Sigma_D'][0], linestyle='dashed', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)

ax.set_ylim(1e-8, 1e5)
ax.set_xlabel('R [AU]')
ax.set_ylabel(r'$\Sigma_{G,D}$ [g cm$^{-2}$]')
ax.set_title('Surface Density')
ax.legend(fontsize=8)
ax.set_xlim(R_in, R_out)

# 2. Dust-to-gas ratio (epsilon)
ax = axes[0, 1]

ax.loglog(disc.R, snapshots['dust_frac'][0], linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)

ax.set_xlabel('R [AU]')
ax.set_ylabel(r'$\epsilon$')
ax.set_title('Total Dust/Gas Ratio')
ax.set_xlim(R_in, R_out)
ax.set_ylim(1e-4, 1e0)

# 3. Stokes number
ax = axes[0, 2]

ax.loglog(disc.R, snapshots['St'][0], linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)

ax.set_xlabel('R [AU]')
ax.set_ylabel('Stokes Number')
ax.set_title('Stokes Number')
ax.set_xlim(R_in, R_out)
ax.set_ylim(1e-10,1e0)

# 4. Pebble size
ax = axes[1, 0]

ax.loglog(disc.R, snapshots['grain_size'][0], linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)

ax.set_xlabel('R [AU]')
ax.set_ylabel('Pebble Size [cm]')
ax.set_title('Pebble Size')
ax.set_xlim(R_in, R_out)

# 5. Pressure
ax = axes[1, 1]
 
ax.loglog(disc.R, np.abs(snapshots['P'][0]), linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)

ax.set_xlabel('R [AU]')
ax.set_ylabel('P')
ax.set_title('Pressure')
ax.set_xlim(R_in, R_out)

# 6. Temperature profile
ax = axes[1, 2]

ax.loglog(disc.R, snapshots['T'][0], linestyle='solid', lw=lw)
ax.axhline(170, ls = 'dashed', label='170 K', color = 'gray', lw=1)

ax.set_xlabel('R [AU]')
ax.set_ylabel('T [K]')
ax.set_title('Temperature Profile')
ax.set_xlim(R_in, R_out)
ax.legend(fontsize=8)

# 7. CO abundance (ice + gas combined)
ax = axes[2, 0]

if idx_CO is not None:
    CO_total = snapshots['chem_ice'][0][idx_CO] + snapshots['chem_gas'][0][idx_CO]  # Sum of ice and gas
    ax.loglog(disc.R, CO_total, linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)

    ax.set_xlabel('R [AU]')
    ax.set_ylabel(r'CO Abundance')
    ax.set_title('CO (Ice + Gas)')
    ax.set_xlim(R_in, R_out)
else:
    ax.text(0.5, 0.5, 'CO not found in chemistry', ha='center', va='center', transform=ax.transAxes)
    ax.set_title('CO (Ice + Gas)')

# 8. H2O abundance (ice + gas combined)
ax = axes[2, 1]

if idx_H2O is not None:
    
    H2O_total = snapshots['chem_ice'][0][idx_H2O] + snapshots['chem_gas'][0][idx_H2O]  # Sum of ice and gas
    ax.loglog(disc.R, H2O_total, linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)
      
    ax.set_xlabel('R [AU]')
    ax.set_ylabel(r'H$_2$O Abundance')
    ax.set_title(r'H$_2$O (Ice + Gas)')
    ax.set_xlim(R_in, R_out)
else:
    ax.text(0.5, 0.5, 'H2O not found in chemistry', ha='center', va='center', transform=ax.transAxes)
    ax.set_title(r'H$_2$O (Ice + Gas)')

# 9. Total volatile abundance (sum of volatile molecules, excluding grains)
ax = axes[2, 2]

if idx_CO is not None:
    # Sum all volatiles (exclude grain species which typically have 'grain' in name)
    volatile_ice = np.sum([snapshots['chem_ice'][0][j] for j in range(len(chem_species)) 
                            if 'grain' not in chem_species[j]], axis=0)
    volatile_gas = np.sum([snapshots['chem_gas'][0][j] for j in range(len(chem_species)) 
                            if 'grain' not in chem_species[j]], axis=0)
    volatile_total = volatile_ice + volatile_gas
    ax.loglog(disc.R, volatile_total, linestyle='solid', label=rf"t={snapshots['t_yr'][0]/1e6:.2f} Myr", lw=lw)
     
    ax.set_xlabel('R [AU]')
    ax.set_ylabel(r'Total Volatile Abundance')
    ax.set_title('Total Volatiles (Ice + Gas)')
    ax.set_xlim(R_in, R_out)
else:
    ax.text(0.5, 0.5, 'Chemistry data not available', ha='center', va='center', transform=ax.transAxes)
    ax.set_title('Total Volatiles (Ice + Gas)')

plt.tight_layout()
plt.show()

# Print chemistry species for reference
if idx_CO is not None:
    print(f"\nChemistry species tracked: {chem_species}")
# Out:
# Chemistry species tracked: ['CO', 'CH4', 'CO2', 'H2O', 'C-grain', 'Si-grain']

# %% [markdown]
# # Evolution

# %%
# 8) Evolve disc
pbar = tqdm(total=run_duration_yr,
             unit='yr',
             desc='Evolving disc... ',
             bar_format='{desc}: {percentage:.1f}%|{bar}| {rate_fmt} [{elapsed}<{remaining}]')
last_elapsed_yr = 0.0
steps = 0
t_yr = driver.t / yr_code


def _safe_rc(disc_obj):
    rout = disc_obj.Rout()
    sigma_g = disc_obj.Sigma_G
    valid = np.isfinite(sigma_g) & (sigma_g > 0)
    if rout <= 0 or np.count_nonzero(valid & (disc_obj.R < rout)) < 2:
        return None
    try:
        return disc_obj.RC()
    except ValueError:
        return None
    

abort = False

while not io.finished() and not abort:
    ti = io.next_event_time()

    while driver.t < ti:
        #Update the dead zone position for this time step
        current_R_dz = compute_R_dz(t_yr, R_dz_initial, R_dz_min, t_initial_yr, 1e6) #use 1e6 since we want it to hit 2AU at 1Myr not 2Myr
        #Update alpha array using grid and eos (no disc needed)
        alpha_turb_array = compute_alpha_turb_array(grid.Rc, eos.H, current_R_dz, alpha_dead, alpha_active, dz_width_scaling)
        
        # Set via the property setter → psi auto-updates
        eos.alpha_t = alpha_turb_array
        # Also update the wind model's psi to stay in sync
        visc_evol._psi = eos.psi

        dt = driver(ti)
        steps += 1

        # Stop cleanly if the state has gone non-finite
        if not (np.isfinite(driver.t) and np.all(np.isfinite(disc.Sigma_G)) and np.all(np.isfinite(disc.T))):
            print("\nStopping early: disc state became non-finite.")
            abort = True
            break

        # pbar progress within the run window only
        t_yr = driver.t / yr_code
        elapsed_yr = max(0.0, t_yr - run_start_yr)
        if np.isfinite(elapsed_yr):
            pbar.update(elapsed_yr - last_elapsed_yr)
            last_elapsed_yr = elapsed_yr 

    # Keep t_yr defined even if no integration step was taken in this event window
    t_yr = driver.t / yr_code

    # Store snapshots at snapshot times
    if io.check_event(driver.t, 'snapshot'):
        snapshots['t_yr'].append(t_yr)
        snapshots['Sigma_G'].append(disc.Sigma_G.copy())
        snapshots['Sigma_D'].append(disc.Sigma_D.sum(axis=0).copy()) #Total dust Sigma, pebbles + grains
        snapshots['dust_frac'].append(disc.dust_frac.sum(axis=0).copy()) #Total dust to gas ratio
        snapshots['St'].append(disc.Stokes()[1].copy()) #Pebbles not small grains
        snapshots['grain_size'].append(disc.grain_size[1].copy()) #Pebbles not small grains
        snapshots['T'].append(disc.T.copy()) #Temp
        snapshots['P'].append(disc.P.copy()) #Pressure
        snapshots['chem_ice'].append(disc.chem.ice.data.copy()) #ice chemistry
        snapshots['chem_gas'].append(disc.chem.gas.data.copy()) #gas chemistry
        snapshots['mid_gas_dens'].append(disc.midplane_gas_density.copy())
        snapshots['rdz'].append(current_R_dz)
        snapshots['alpha'].append(alpha_turb_array.copy())
        snapshots['H'].append(disc.H.copy())
    
        #Torque map data 
        TypeI = pf.TypeIMigration(disc) #Creates a Type I migration object from the disc object
        Torque_map = np.zeros_like(R_grid) #initialize 2D grid with all values zero 
        #Compute Torques
        for i, Mp in enumerate(mass_array):
            #Pass Mp as an array of the same shape as radius_array
            Mp_array = np.ones_like(radius_array) * Mp #entire row with said mass value
            #Compute the total torque for said mass at each R 
            Torque_map[i, :] = TypeI.compute_torque_raw(radius_array, Mp_array)
        torque_maps['t_yr'].append(t_yr)
        torque_maps['maps'].append(Torque_map)

        io.pop_events(driver.t, 'snapshot')

    # Store at output times
    if io.check_event(driver.t, 'save'):
        dt_current = visc_evol.max_timestep(disc)
        history['t_yr'].append(t_yr)
        history['Mtot'].append(disc.Mtot() * u.g.to(u.solMass))
        history['Rout'].append(disc.Rout())
        history['dt_yr'].append(dt_current / yr_code)
        rc_value = _safe_rc(disc)
        history['Rc'].append(rc_value)
        if rc_value is None:
            print("  Skipping RC fit: disc is empty or non-finite.")
        io.pop_events(driver.t, 'save')

pbar.close()
print(f"\n=== EVOLUTION COMPLETE ===")
print(f"Total steps: {steps}")
print(f"Final time: {driver.t/yr_code:.1e} years")
print(f"Final mass: {history['Mtot'][-1]:.3e} M_sun ({100*history['Mtot'][-1]/history['Mtot'][0]:.1f}% of initial)")
print(f"Final disc outer radius: {disc.Rout():.2f} AU")
print(f"Average dt: {np.mean(history['dt_yr']):.1f} years")

Rout_initial = history['Rout'][0]
Rout_final = disc.Rout()  # or history['Rout'][-1]

print(f"Initial Rout: {Rout_initial:.2f} AU")
print(f"Final Rout:   {Rout_final:.2f} AU")
print(f"Delta Rout:   {Rout_final - Rout_initial:+.2f} AU")
print(f"Percent change: {(Rout_final / Rout_initial - 1)*100:+.2f}%")

print("Initial Rc (input):", Rc.value)
print("Initial Rout(thresh=1e-5):", history['Rout'][0])
print("Final   Rout(thresh=1e-5):", history['Rout'][-1])
rc_value = _safe_rc(disc)
print("Current fitted RC():", rc_value if rc_value is not None else "unavailable")
# Out:
# Evolving disc... : 0.0%|          | ?yr/s [00:00<?]
# === EVOLUTION COMPLETE ===
# Total steps: 152344
# Final time: 2.0e+06 years
# Final mass: 1.479e-01 M_sun (63.2% of initial)
# Final disc outer radius: 120.00 AU
# Average dt: 24.7 years
# Initial Rout: 120.00 AU
# Final Rout:   120.00 AU
# Delta Rout:   +0.00 AU
# Percent change: +0.00%
# Initial Rc (input): 91.0
# Initial Rout(thresh=1e-5): 120.0
# Final   Rout(thresh=1e-5): 120.0
# Current fitted RC(): 2325987.0971947038

# %%
# Plot evolution results with dust properties and chemistry
fig, axes = plt.subplots(3, 3, figsize=(15, 15))
lw = 1.5

# Get chemical species names and find indices
try:
    chem_species = disc.chem.ice.names
    idx_CO = chem_species.index('CO') if 'CO' in chem_species else None
    idx_H2O = chem_species.index('H2O') if 'H2O' in chem_species else None
    idx_CH4 = chem_species.index('CH4') if 'CH4' in chem_species else None
except (AttributeError, ValueError):
    idx_CO = idx_H2O = idx_CH4 = None

# Color cycle for time snapshots
from cycler import cycler
c = ['blue','orange','g','r']
ax_prop_cycle = cycler(color=c)

# 1. Surface density: Gas and Dust
ax = axes[0, 0]
ax.set_prop_cycle(ax_prop_cycle)

i = 0
for line in snapshots['Sigma_G']:
    ax.loglog(disc.R, line, linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
    i += 1

i = 0
for line in snapshots['Sigma_D']:
    ax.loglog(disc.R, line, linestyle='dashed', lw=lw)
    i += 1
ax.set_ylim(1e-8, 1e5)
ax.set_xlabel('R [AU]')
ax.set_ylabel(r'$\Sigma_{G,D}$ [g cm$^{-2}$]')
ax.set_title('Surface Density')
ax.legend(fontsize=8)
ax.set_xlim(R_in, R_out)

# 2. Dust-to-gas ratio (epsilon)
ax = axes[0, 1]
ax.set_prop_cycle(ax_prop_cycle)

i = 0
for line in snapshots['dust_frac']:
    ax.loglog(disc.R, line, linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
    i += 1

ax.set_xlabel('R [AU]')
ax.set_ylabel(r'$\epsilon$')
ax.set_title('Total Dust/Gas Ratio')
ax.set_xlim(R_in, R_out)
ax.set_ylim(1e-8, 1e0)

# 3. Stokes number
ax = axes[0, 2]
ax.set_prop_cycle(ax_prop_cycle)

i = 0
for line in snapshots['St']:
    ax.loglog(disc.R, line, linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
    i += 1

ax.set_xlabel('R [AU]')
ax.set_ylabel('Stokes Number')
ax.set_title('Stokes Number')
ax.set_xlim(R_in, R_out)
ax.set_ylim(1e-8, 1e0)

# 4. Pebble size
ax = axes[1, 0]
ax.set_prop_cycle(ax_prop_cycle)

i = 0
for line in snapshots['grain_size']:
    ax.loglog(disc.R, line, linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
    i += 1

ax.set_xlabel('R [AU]')
ax.set_ylabel('Pebble Size [cm]')
ax.set_title('Pebble Size')
ax.set_xlim(R_in, R_out)

# 5. Pressure
ax = axes[1, 1]
ax.set_prop_cycle(ax_prop_cycle)

i = 0
for line in snapshots['P']:
    ax.loglog(disc.R, np.abs(line), linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
    i += 1
ax.set_xlabel('R [AU]')
ax.set_ylabel('P')
ax.set_title('Pressure')
ax.set_xlim(R_in, R_out)

# 6. Temperature profile
ax = axes[1, 2]
ax.set_prop_cycle(ax_prop_cycle)

i = 0
for line in snapshots['T']:
    ax.loglog(disc.R, line, linestyle='solid', lw=lw)
    i += 1
ax.axhline(170, ls = 'dashed', label='170 K', color = 'gray', lw=1)

ax.set_xlabel('R [AU]')
ax.set_ylabel('T [K]')
ax.set_title('Temperature Profile')
ax.set_xlim(R_in, R_out)
ax.legend(fontsize=8)

# 7. CO abundance (ice + gas combined)
ax = axes[2, 0]
ax.set_prop_cycle(ax_prop_cycle)

if idx_CO is not None:
    i = 0
    for ice_data, gas_data in zip(snapshots['chem_ice'], snapshots['chem_gas']):
        CO_total = ice_data[idx_CO] + gas_data[idx_CO]  # Sum of ice and gas
        ax.loglog(disc.R, CO_total, linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
        i += 1
    ax.set_xlabel('R [AU]')
    ax.set_ylabel(r'CO Abundance')
    ax.set_title('CO (Ice + Gas)')
    ax.set_xlim(R_in, R_out)
else:
    ax.text(0.5, 0.5, 'CO not found in chemistry', ha='center', va='center', transform=ax.transAxes)
    ax.set_title('CO (Ice + Gas)')

# 8. H2O abundance (ice + gas combined)
ax = axes[2, 1]
ax.set_prop_cycle(ax_prop_cycle)

if idx_H2O is not None:
    i = 0
    for ice_data, gas_data in zip(snapshots['chem_ice'], snapshots['chem_gas']):
        H2O_total = ice_data[idx_H2O] + gas_data[idx_H2O]  # Sum of ice and gas
        ax.loglog(disc.R, H2O_total, linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
        i += 1
    ax.set_xlabel('R [AU]')
    ax.set_ylabel(r'H$_2$O Abundance')
    ax.set_title(r'H$_2$O (Ice + Gas)')
    ax.set_xlim(R_in, R_out)
else:
    ax.text(0.5, 0.5, 'H2O not found in chemistry', ha='center', va='center', transform=ax.transAxes)
    ax.set_title(r'H$_2$O (Ice + Gas)')

# 9. Total volatile abundance (sum of volatile molecules, excluding grains)
ax = axes[2, 2]
ax.set_prop_cycle(ax_prop_cycle)

if idx_CO is not None:
    i = 0
    for ice_data, gas_data in zip(snapshots['chem_ice'], snapshots['chem_gas']):
        # Sum all volatiles (exclude grain species which typically have 'grain' in name)
        volatile_ice = np.sum([ice_data[j] for j in range(len(chem_species)) 
                               if 'grain' not in chem_species[j]], axis=0)
        volatile_gas = np.sum([gas_data[j] for j in range(len(chem_species)) 
                               if 'grain' not in chem_species[j]], axis=0)
        volatile_total = volatile_ice + volatile_gas
        ax.loglog(disc.R, volatile_total, linestyle='solid', label=rf"t={snapshots['t_yr'][i]/1e6:.2f} Myr", lw=lw)
        i += 1
    ax.set_xlabel('R [AU]')
    ax.set_ylabel(r'Total Volatile Abundance')
    ax.set_title('Total Volatiles (Ice + Gas)')
    ax.set_xlim(R_in, R_out)
else:
    ax.text(0.5, 0.5, 'Chemistry data not available', ha='center', va='center', transform=ax.transAxes)
    ax.set_title('Total Volatiles (Ice + Gas)')

plt.tight_layout()
plt.savefig('output/Simple/disc_plots.jpg', dpi =300)
plt.show()

# Print chemistry species for reference
if idx_CO is not None:
    print(f"\nChemistry species tracked: {chem_species}")
# Out:
# Chemistry species tracked: ['CO', 'CH4', 'CO2', 'H2O', 'C-grain', 'Si-grain']

# %%
from matplotlib.colors import CenteredNorm
from matplotlib import colors
from DiscEvolution import planet_formation as pf

TypeI = pf.TypeIMigration(disc)

R_grid_1d = disc.R
M_grid_1d = np.logspace(-2, 3, Ncells)

GL = np.zeros((len(M_grid_1d), len(R_grid_1d)))
GC = np.zeros_like(GL)

for i, M in enumerate(M_grid_1d):
    GL[i], GC[i] = TypeI.compute_torque_components_raw(R_grid_1d, M)

R_grid, M_grid = np.meshgrid(R_grid_1d, M_grid_1d)
fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

for ax, data, title in zip(axes, [GL, GC], ['Lindblad', 'Corotation']):
    vmin = np.nanpercentile(data, 2)
    vmax = np.nanpercentile(data, 98)
    abs_max = max(abs(vmin), abs(vmax))
    norm = colors.TwoSlopeNorm(vmin=-abs_max, vcenter=0.0, vmax=abs_max)
    levels = np.linspace(-abs_max, abs_max, 100)
    cp = ax.contourf(R_grid, M_grid, data, levels=levels, cmap='RdBu', norm=norm, extend='both')
    ax.contour(R_grid, M_grid, data, levels=[0.0], colors='black', linewidths=1.0)
    ax.set_xscale('log'); ax.set_yscale('log')
    ax.set_xlabel('R [AU]'); ax.set_ylabel(r'$M_p\,[M_\oplus]$')
    ax.set_title(title + ' torque')
    ax.set_xlim(min(disc.R), max(disc.R))
    plt.colorbar(cp, ax=ax, label=r'$\Gamma / \Gamma_0$')

plt.tight_layout()
plt.show()

# %%
from matplotlib.colors import CenteredNorm
from matplotlib import colors
from DiscEvolution import planet_formation as pf

TypeI = pf.TypeIMigration(disc)

R_grid_1d = disc.R
M_grid_1d = np.logspace(-2, 3, Ncells)

GL = np.zeros((len(M_grid_1d), len(R_grid_1d)))
GC = np.zeros_like(GL)

for i, M in enumerate(M_grid_1d):
    GL[i], GC[i] = TypeI.compute_torque_components_raw(R_grid_1d, M)

R_grid, M_grid = np.meshgrid(R_grid_1d, M_grid_1d)

fig, ax = plt.subplots(figsize=(10, 6))


#cmin = np.nanmin(data)
#cmax = np.nanmax(data)
cmin = -5
cmax = 5
norm = colors.TwoSlopeNorm(vmin=cmin, vcenter=0.0, vmax=cmax)
#norm = CenteredNorm()
cp = ax.contourf(R_grid, M_grid, GC, levels=10, cmap='RdBu', norm=norm)
ax.contour(R_grid, M_grid, data, levels=[0.0], colors='black', linewidths=1.0)
ax.set_xscale('log'); ax.set_yscale('log')
ax.set_xlabel('R [AU]'); ax.set_ylabel(r'$M_p\,[M_\oplus]$')
ax.set_title(title + ' torque')
ax.set_xlim(min(disc.R), max(disc.R)) 
plt.colorbar(cp, ax=ax, label=r'$\Gamma / \Gamma_0$')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

vmin_percentile = np.nanpercentile(tmap, 2)   # 2nd percentile
vmax_percentile = np.nanpercentile(tmap, 98)  # 98th percentile
abs_max = max(abs(vmin_percentile), abs(vmax_percentile))

# Create symmetric norm centered at zero
norm = colors.TwoSlopeNorm(vmin=-abs_max, vcenter=0.0, vmax=abs_max)
symmetric_levels = np.linspace(-abs_max, abs_max, 100)

cp = ax.contourf(R_grid, M_grid, tmap, levels=symmetric_levels, cmap='RdBu', norm=norm, extend='both')

# Zero-Torque Planet Traps
trap_lines = ax.contour(R_grid, M_grid, tmap, levels=[0.0], colors='black', linewidths=1.0)

# Colorbar
tick_positions = np.linspace(-abs_max, abs_max, 9)  # 9 evenly spaced ticks
cbar = plt.colorbar(cp, ax=ax, ticks=tick_positions) 
#cbar = plt.colorbar(cp, ax=ax, ticks = np.arange(-5.0, 6.0, 1.0))
cbar.set_label(rf'torque $\Gamma / \Gamma_0$', fontsize=12)

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(min(disc.R), R_out) 
#ax.set_ylim(0.1, 100)

ax.set_xlabel('Radius [AU]', fontsize=12)
ax.set_ylabel(rf'Planet Mass [$M_\oplus$]', fontsize=12)
timelabel = f"{torque_maps['t_yr'][i] / 1e6:.1f}"
ax.set_title(rf't = {timelabel} Myr', fontsize=14)

ax.axvline(R_ht, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ht, ax.get_ylim()[1], f'Heat trans.  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_ice, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ice, ax.get_ylim()[1], f'Ice line  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_dz_now, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_dz_now, ax.get_ylim()[1], f'Dead Zone  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')

plt.tight_layout()
#plt.savefig('output/Simple/Psi_array_torques'+timelabel+'_Myr_new.jpg', dpi=300)
plt.show()

# %% [markdown]
# # Trap Radii

# %% [raw]
# ##FOR IRRADIATEDEOS
# # Compute trap radii (self-contained — no dependency on later cells)
# from DiscEvolution.constants import Omega0, GasConst, sig_SB, AU
#
# _R = disc.R
# _T = disc.T
# _Sigma = disc.Sigma_G
# _Om_k = Omega0 * star.Omega_k(_R)
# _cs = np.sqrt(GasConst * _T / eos._mu)
# _H = _cs / _Om_k
# _sqrt2pi = np.sqrt(2 * np.pi)
# _kappa = eos._kappa(_Sigma / (_sqrt2pi * _H), _T, 1e-5)
# _tau = 0.5 * _Sigma * _kappa
# _H_au = _H / AU
#
# # Stellar irradiation flux → equivalent temperature
# _X = star.Rau / _R
# _f_flat = (2 / (3 * np.pi)) * _X**3
# _f_flare = 0.5 * eos._dlogHdlogRm1 * _X**2
# _F_irr = sig_SB * star.T_eff**4 * (_f_flat + _f_flare * (_H_au / _R))
# _T_irr = (_F_irr / sig_SB)**0.25
#
# # Viscous + wind heating flux → equivalent temperature
# _alpha_arr = np.atleast_1d(eos._alpha_t)
# _visc_heat = eos._e_rad * 1.125 * _alpha_arr * _cs * _cs * _Om_k * (1 + eos._psi / 3)
# _F_visc = _visc_heat * (0.375 * _tau * _Sigma + 1.0 / _kappa)
# _T_visc = (_F_visc / sig_SB)**0.25
#
# # --- Trap radii ---
# # 1) Heat transition: where T_irr ≈ T_visc
# cross_idx = np.argmin(np.abs(_T_irr - _T_visc))
# R_ht = _R[cross_idx]
#
# # 2) Ice line: where T crosses 170 K
# ice_idx = np.argmin(np.abs(_T - 170))
# R_ice = _R[ice_idx]
#
# # 3) Dead zone edge (current time)
# R_dz_now = compute_R_dz(driver.t / yr_code, R_dz_initial, R_dz_min, t_initial_yr, t_final_yr)
#
# print(f"Heat transition:  R_ht  = {R_ht:.2f} AU  (T ≈ {_T[cross_idx]:.0f} K)")
# print(f"Ice line:         R_ice = {R_ice:.2f} AU  (T ≈ {_T[ice_idx]:.0f} K)")
# print(f"Dead zone edge:   R_dz  = {R_dz_now:.2f} AU")

# %%
## FOR SIMPLEEOS
# Compute trap radii (self-contained, SimpleDiscEOS version)
_R = disc.R
_T = disc.T
_Sigma = disc.Sigma_G

# Irradiation temperature: T_irr = Tirr0 * R^(-3/7)
_T_irr = eos._Tirr0 * _R**(-3/7.)

# Viscous temperature: T_vis = Tnu * sqrt((1+psi)*e_rad) * Sigma * R^(-0.75)
_T_visc = (eos._Tnu * np.sqrt((1 + eos._psi) * eos._e_rad)
           * _Sigma * _R**-0.75)

# --- Trap radii ---
# 1) Heat transition: where T_irr ≈ T_visc
cross_idx = np.argmin(np.abs(_T_irr - _T_visc))
R_ht = _R[cross_idx]

# 2) Ice line: where T crosses 170 K
ice_idx = np.argmin(np.abs(_T - 170))
R_ice = _R[ice_idx]

# 3) Dead zone edge (current time)
R_dz_now = compute_R_dz(driver.t / yr_code, R_dz_initial, R_dz_min, t_initial_yr, t_final_yr)

print(f"Heat transition:  R_ht  = {R_ht:.2f} AU  (T ≈ {_T[cross_idx]:.0f} K)")
print(f"Ice line:         R_ice = {R_ice:.2f} AU  (T ≈ {_T[ice_idx]:.0f} K)")
print(f"Dead zone edge:   R_dz  = {R_dz_now:.2f} AU")
# Out:
# Heat transition:  R_ht  = 3.15 AU  (T ≈ 138 K)
# Ice line:         R_ice = 2.31 AU  (T ≈ 171 K)
# Dead zone edge:   R_dz  = 1.00 AU

# %%
from matplotlib import colors

i = 0
for tmap in torque_maps['maps']: 
    fig, ax = plt.subplots(figsize=(10, 6))

    # Colormap (Red = Inward/negative, Blue = Outward/Positive)
    #norm = colors.TwoSlopeNorm(vmin=-5.0, vcenter=0.0, vmax=5.0)

    #norm = colors.CenteredNorm()
    #symmetric_levels = np.linspace(-5.0, 5.0, 100) #Explicitly define 100 levels from -5 to +5

    #data_min = np.nanmin(tmap)
    #data_max = np.nanmax(tmap)
    #abs_max = max(abs(data_min), abs(data_max))
    vmin_percentile = np.nanpercentile(tmap, 2)   # 2nd percentile
    vmax_percentile = np.nanpercentile(tmap, 98)  # 98th percentile
    abs_max = max(abs(vmin_percentile), abs(vmax_percentile))

    # Create symmetric norm centered at zero
    norm = colors.TwoSlopeNorm(vmin=-abs_max, vcenter=0.0, vmax=abs_max)
    symmetric_levels = np.linspace(-abs_max, abs_max, 100)
    
    cp = ax.contourf(R_grid, M_grid, tmap, levels=symmetric_levels, cmap='RdBu', norm=norm, extend='both')

    # Zero-Torque Planet Traps
    trap_lines = ax.contour(R_grid, M_grid, tmap, levels=[0.0], colors='black', linewidths=1.0)

    # Colorbar
    tick_positions = np.linspace(-abs_max, abs_max, 9)  # 9 evenly spaced ticks
    cbar = plt.colorbar(cp, ax=ax, ticks=tick_positions) 
    #cbar = plt.colorbar(cp, ax=ax, ticks = np.arange(-5.0, 6.0, 1.0))
    cbar.set_label(rf'torque $\Gamma / \Gamma_0$', fontsize=12)

    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlim(min(disc.R), R_out) 
    #ax.set_ylim(0.1, 100)

    ax.set_xlabel('Radius [AU]', fontsize=12)
    ax.set_ylabel(rf'Planet Mass [$M_\oplus$]', fontsize=12)
    timelabel = f"{torque_maps['t_yr'][i] / 1e6:.1f}"
    ax.set_title(rf't = {timelabel} Myr', fontsize=14)

    ax.axvline(R_ht, ls='--', color='black', lw=1.2, alpha=0.7)
    ax.text(R_ht, ax.get_ylim()[1], f'Heat trans.  ', color='black', fontsize=8,
            va='top', ha='left', rotation=90, backgroundcolor='none')
    ax.axvline(R_ice, ls='--', color='black', lw=1.2, alpha=0.7)
    ax.text(R_ice, ax.get_ylim()[1], f'Ice line  ', color='black', fontsize=8,
            va='top', ha='left', rotation=90, backgroundcolor='none')
    ax.axvline(R_dz_now, ls='--', color='black', lw=1.2, alpha=0.7)
    ax.text(R_dz_now, ax.get_ylim()[1], f'Dead Zone  ', color='black', fontsize=8,
            va='top', ha='left', rotation=90, backgroundcolor='none')

    plt.tight_layout()
    plt.savefig('output/Simple/Psi_array_torques'+timelabel+'_Myr_new.jpg', dpi=300)
    plt.show()
    print('min: '+str(float(np.min(tmap)))+', max: '+str(float(np.max(tmap))))
    i = i + 1
# Out:
# min: -5.380744233144473, max: -2.5496097917947425
# min: -88.45669458977756, max: 26.95808948558729
# min: -69.31600838550176, max: 28.63593523131106
# min: -69.08504113438289, max: 28.4570760419417

# %% [markdown]
# # Diagnostics

# %% [markdown]
# ## alphas

# %%
# Diagnostic: alpha profiles from internal objects
fig, ax = plt.subplots(figsize=(9, 6))

# Alpha_turb: what the EOS actually stores (drives thermal balance + dust physics)
alpha_turb_from_eos = eos.alpha  # eos._alpha, set by _f_alpha(R) → _alpha_t

# Alpha_wind: psi * alpha_turb (how HybridWindModel computes wind velocity internally)
alpha_wind_from_model = visc_evol._psi * alpha_turb_from_eos

# Alpha_eff: total effective alpha driving gas evolution
alpha_eff_from_model = alpha_turb_from_eos * (1.0 + visc_evol._psi)

# Also extract nu directly and back out alpha_eff from it
# disc.nu = eos.nu = alpha_t * cs * H (turbulent only)
# The wind adds psi*nu implicitly in HybridWindModel._init_fluxes_wind
alpha_from_nu = disc.nu / (disc.cs * disc.H)  # should match alpha_turb_from_eos

ax.loglog(disc.R, alpha_turb_from_eos, label=r'$\alpha_{\rm turb}$ (eos.alpha)', lw=2, color='blue')
ax.loglog(disc.R, alpha_wind_from_model, label=r'$\alpha_{wind}$', lw=2, color='orange')
ax.loglog(disc.R, alpha_eff_from_model, label=r'$\alpha_{\rm eff}$ ($\alpha_{\rm turb}(1+\psi)$)', lw=2, color='red')
ax.loglog(disc.R, alpha_from_nu, label=r'$\nu / (c_s H)$ (back-calculated)', lw=1, ls='--', color='lime')

ax.set_xlabel('Radius [AU]', fontsize=12)
ax.set_ylabel(r'$\alpha$', fontsize=12)
ax.set_title(r'Alpha profiles from disc/eos/visc objects', fontsize=13, fontweight='bold')
ax.legend(fontsize=9, loc='best')
ax.grid(True, which='both', alpha=0.3)
ax.set_xlim(R_in, R_out)

# Print scalar checks
#print(f"psi (from HybridWindModel): {visc_evol._psi}")
print(f"eos._alpha_t type: {type(eos._alpha_t)}, shape: {np.shape(eos._alpha_t)}")
print(f"eos._alpha_t range: [{np.min(eos._alpha_t):.2e}, {np.max(eos._alpha_t):.2e}]")
print(f"disc.alpha range:   [{np.min(disc.alpha):.2e}, {np.max(disc.alpha):.2e}]")
print(f"nu/(cs*H) matches eos.alpha: {np.allclose(alpha_from_nu, alpha_turb_from_eos)}")

ax.axvline(R_ht, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ht, ax.get_ylim()[1], f'Heat trans.  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_ice, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ice, ax.get_ylim()[1], f'Ice line  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_dz_now, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_dz_now, ax.get_ylim()[1], f'Dead Zone  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')

plt.tight_layout()
plt.savefig('output/Simple/alphavsR psi arr_new.jpg', dpi=300)
plt.show()
# Out:
# eos._alpha_t type: <class 'numpy.ndarray'>, shape: (500,)
# eos._alpha_t range: [1.00e-05, 9.90e-04]
# disc.alpha range:   [1.00e-05, 9.90e-04]
# nu/(cs*H) matches eos.alpha: True

# %% [markdown]
# ## Mdot

# %%
visc_evol.viscous_velocity(disc, disc.Sigma).shape
# Out:
# (499,)

# %%
vr = visc_evol.viscous_velocity(disc, disc.Sigma)
mdot_profile = disc.Mdot(vr)     # profile across grid
mdot_inner = mdot_profile[0]     # usually the stellar accretion rate
print(mdot_inner)
# Out:
# 9.005429788423146e-09

# %%
# Diagnostic: Mdot(R) profile — total and decomposed into viscous vs wind
from DiscEvolution.constants import AU, yr, Msun

# Call viscous_velocity to populate internal flux arrays
vr = visc_evol.viscous_velocity(disc, disc.Sigma)

# Face-midpoint radii and interpolated Sigma (vr has length N-1)
R_face = 0.5 * (disc.R[1:] + disc.R[:-1])
Sigma_face = 0.5 * (disc.Sigma[1:] + disc.Sigma[:-1])

# Total Mdot(R) = -2π R Σ vr   [convert to Msun/yr]
unit_conv = AU**2 * yr / Msun
mdot_total = -2.0 * np.pi * R_face * Sigma_face * vr * unit_conv

# Decompose: viscous and wind flux contributions (stored after viscous_velocity call)
f_visc_face = visc_evol._f_visc[1:-1]
f_wind_face = visc_evol._f_wind[1:-1]

vr_visc = -2.0 * f_visc_face / (disc.Sigma[1:] + disc.Sigma[:-1])
vr_wind = -2.0 * f_wind_face / (disc.Sigma[1:] + disc.Sigma[:-1])

mdot_visc = -2.0 * np.pi * R_face * Sigma_face * vr_visc * unit_conv
mdot_wind = -2.0 * np.pi * R_face * Sigma_face * vr_wind * unit_conv

fig, ax = plt.subplots(figsize=(9, 6))

ax.plot(R_face, mdot_total, lw=2, color='black', label=r'$\dot{M}_{\rm total}$')
ax.plot(R_face, mdot_visc, lw=1.5, ls='--', color='blue', label=r'$\dot{M}_{\rm visc}$')
ax.plot(R_face, mdot_wind, lw=1.5, ls='--', color='orange', label=r'$\dot{M}_{\rm wind}$')

ax.set_xscale('log')
ax.set_xlabel('Radius [AU]', fontsize=12)
ax.set_ylabel(r'$\dot{M}(R)$ [M$_\odot$ yr$^{-1}$]', fontsize=12)
ax.set_title(f'Local accretion rate profile  (t = {driver.t/yr_code/1e6:.2f} Myr)', fontsize=13, fontweight='bold')
ax.legend(fontsize=10)
ax.grid(True, which='both', alpha=0.3)
ax.set_xlim(R_in, R_out)

ax.axvline(R_ht, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ht, ax.get_ylim()[1], f'Heat trans.  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_ice, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ice, ax.get_ylim()[1], f'Ice line  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_dz_now, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_dz_now, ax.get_ylim()[1], f'Dead Zone  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')

plt.tight_layout()
plt.savefig('output/Simple/mdotvsR psi arr_new.jpg', dpi=300)
plt.show()
# Out:
# Inner Mdot (total): 9.446e-09 Msun/yr
# Outer Mdot (total): 2.556e-09 Msun/yr
# Mdot range: [2.551e-09, 1.624e-08]
# Mdot std/mean: 49.44%

# %% [markdown]
# ## Temperature

# %% [raw]
# ##FOR IRRADIATEDEOS
# # Diagnostic: Temperature decomposition — T_eff, T_irr, T_visc vs R
# from DiscEvolution.constants import Omega0, GasConst, sig_SB, AU
#
# R = disc.R
# Sigma = disc.Sigma_G
# T = disc.T
#
# mu_val = eos._mu
# Om_k = Omega0 * star.Omega_k(R)
# cs = np.sqrt(GasConst * T / mu_val)
# H = cs / Om_k
# sqrt2pi = np.sqrt(2 * np.pi)
# kappa = eos._kappa(Sigma / (sqrt2pi * H), T, 1e-5)
# tau = 0.5 * Sigma * kappa
# H_au = H / AU
#
# # 1) External irradiation (nebular background)
# #F_ext = sig_SB * eos._Tc**4
#
# # 2) Stellar irradiation
# X = star.Rau / R
# f_flat = (2 / (3 * np.pi)) * X**3
# f_flare = 0.5 * eos._dlogHdlogRm1 * X**2
# F_irr = sig_SB * star.T_eff**4 * (f_flat + f_flare * (H_au / R))
#
# # 3) Viscous (+ wind) heating
# alpha_arr = np.atleast_1d(eos._alpha_t)
# visc_heat = eos._e_rad * 1.125 * alpha_arr * cs * cs * Om_k * (1 + eos._psi / 3)
# F_visc = visc_heat * (0.375 * tau * Sigma + 1.0 / kappa)
#
# # Convert heating fluxes to equivalent temperatures: F = σ T⁴  →  T = (F/σ)^(1/4)
# #T_ext = (F_ext / sig_SB)**0.25 * np.ones_like(R)
# T_irr = (F_irr / sig_SB)**0.25
# T_visc = (F_visc / sig_SB)**0.25
# #T_total = ((F_ext + F_irr + F_visc) / sig_SB)**0.25  # should ≈ disc.T
#
# fig, ax = plt.subplots(figsize=(9, 6))
#
# ax.loglog(R, T, lw=2.5, color='black', label=r'$T_{\rm disc}$ (solved)')
# #ax.loglog(R, T_total, lw=1, ls='--', color='gray', label=r'$(F_{\rm ext}+F_{\rm irr}+F_{\rm visc})^{1/4}/\sigma^{1/4}$')
# ax.loglog(R, T_irr, lw=1.5, color='red', label=r'$T_{\rm irr}$ (stellar)')
# ax.loglog(R, T_visc, lw=1.5, color='orange', label=r'$T_{\rm visc}$ (accretion + wind)')
# #ax.loglog(R, T_ext, lw=1, ls=':', color='blue', label=rf'$T_{{ext}}$ = {eos._Tc} K (nebular)')
# ax.axhline(170, ls='dashed', color='gray', lw=0.8, alpha=0.5, label='170 K (water ice)')
#
# ax.set_xlabel('Radius [AU]', fontsize=12)
# ax.set_ylabel('Temperature [K]', fontsize=12)
# ax.set_title(f'Temperature decomposition  (t = {driver.t/yr_code/1e6:.2f} Myr)', fontsize=13, fontweight='bold')
# ax.legend(fontsize=9, loc='best')
# ax.grid(True, which='both', alpha=0.3)
# ax.set_xlim(R_in, R_out)
#
# ax.axvline(R_ht, ls='--', color='black', lw=1.2, alpha=0.7)
# ax.text(R_ht, ax.get_ylim()[1], f'Heat trans.  ', color='black', fontsize=8,
#         va='top', ha='left', rotation=90, backgroundcolor='none')
# ax.axvline(R_ice, ls='--', color='black', lw=1.2, alpha=0.7)
# ax.text(R_ice, ax.get_ylim()[1], f'Ice line  ', color='black', fontsize=8,
#         va='top', ha='left', rotation=90, backgroundcolor='none')
# ax.axvline(R_dz_now, ls='--', color='black', lw=1.2, alpha=0.7)
# ax.text(R_dz_now, ax.get_ylim()[1], f'Dead Zone  ', color='black', fontsize=8,
#         va='top', ha='left', rotation=90, backgroundcolor='none')
#
# plt.tight_layout()
# plt.savefig('output/Simple/TvsR psi arr.jpg', dpi=300)
# plt.show()
#
# # Print where each component dominates
# cross_idx = np.argmin(np.abs(T_irr - T_visc))
# print(f"T_irr = T_visc crossover at R ≈ {R[cross_idx]:.1f} AU  (T ≈ {T[cross_idx]:.0f} K)")
# print(f"Inner edge: T_visc={T_visc[0]:.0f} K, T_irr={T_irr[0]:.0f} K, T_disc={T[0]:.0f} K")
# #print(f"T_total ≈ T_disc match: {np.allclose(T_total, T, rtol=0.05)}")

# %%
##FOR SIMPLE EOS
## FOR SIMPLEEOS
# Compute trap radii (self-contained, SimpleDiscEOS version)
R = disc.R
T = disc.T
Sigma = disc.Sigma_G

# Irradiation temperature: T_irr = Tirr0 * R^(-3/7)
T_irr = eos._Tirr0 * R**(-3/7.)

# Viscous temperature: T_vis = Tnu * sqrt((1+psi)*e_rad) * Sigma * R^(-0.75)
T_visc = (eos._Tnu * np.sqrt((1 + eos._psi) * eos._e_rad)
           * Sigma * R**-0.75)



fig, ax = plt.subplots(figsize=(9, 6))

ax.loglog(R, T, lw=2.5, color='black', label=r'$T_{\rm disc}$ (solved)')
#ax.loglog(R, T_total, lw=1, ls='--', color='gray', label=r'$(F_{\rm ext}+F_{\rm irr}+F_{\rm visc})^{1/4}/\sigma^{1/4}$')
ax.loglog(R, T_irr, lw=1.5, color='red', label=r'$T_{\rm irr}$ (stellar)')
ax.loglog(R, T_visc, lw=1.5, color='orange', label=r'$T_{\rm visc}$ (accretion + wind)')
#ax.loglog(R, T_ext, lw=1, ls=':', color='blue', label=rf'$T_{{ext}}$ = {eos._Tc} K (nebular)')
ax.axhline(170, ls='dashed', color='gray', lw=0.8, alpha=0.5, label='170 K (water ice)')

ax.set_xlabel('Radius [AU]', fontsize=12)
ax.set_ylabel('Temperature [K]', fontsize=12)
ax.set_title(f'Temperature decomposition  (t = {driver.t/yr_code/1e6:.2f} Myr)', fontsize=13, fontweight='bold')
ax.legend(fontsize=9, loc='best')
ax.grid(True, which='both', alpha=0.3)
ax.set_xlim(R_in, R_out)

ax.axvline(R_ht, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ht, ax.get_ylim()[1], f'Heat trans.  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_ice, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_ice, ax.get_ylim()[1], f'Ice line  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')
ax.axvline(R_dz_now, ls='--', color='black', lw=1.2, alpha=0.7)
ax.text(R_dz_now, ax.get_ylim()[1], f'Dead Zone  ', color='black', fontsize=8,
        va='top', ha='left', rotation=90, backgroundcolor='none')

plt.tight_layout()
plt.savefig('output/Simple/TvsR psi arr_new.jpg', dpi=300)
plt.show()

# Print where each component dominates
cross_idx = np.argmin(np.abs(T_irr - T_visc))
print(f"T_irr = T_visc crossover at R ≈ {R[cross_idx]:.1f} AU  (T ≈ {T[cross_idx]:.0f} K)")
print(f"Inner edge: T_visc={T_visc[0]:.0f} K, T_irr={T_irr[0]:.0f} K, T_disc={T[0]:.0f} K")
#print(f"T_total ≈ T_disc match: {np.allclose(T_total, T, rtol=0.05)}")
# Out:
# T_irr = T_visc crossover at R ≈ 3.1 AU  (T ≈ 138 K)
# Inner edge: T_visc=19977 K, T_irr=484 K, T_disc=2108 K

# %% [raw]
# # 11) Generate Torque Map Evolution Movie
# import os
# from matplotlib import colors
#
# print("\n=== GENERATING TORQUE MAP MOVIE ===")
#
# # Create output directory
# movie_dir = 'output/torque_movie'
# os.makedirs(movie_dir, exist_ok=True)
#
# # Generate all frames
# for snap_idx, t_yr in tqdm(enumerate(torque_maps['t_yr']),
#                            total=len(torque_maps['t_yr']),
#                            desc='Rendering frames'):
#
#     fig, ax = plt.subplots(figsize=(10, 7))
#
#     Torque_map_frame = torque_maps['maps'][snap_idx]
#
#     # Torque map
#     norm = colors.TwoSlopeNorm(vmin=-5.0, vcenter=0.0, vmax=5.0)
#     symmetric_levels = np.linspace(-5.0, 5.0, 100)
#
#     cp = ax.contourf(R_grid, M_grid, Torque_map_frame,
#                       levels=symmetric_levels, cmap='RdBu', norm=norm, extend='both')
#
#     # Zero-torque planet traps
#     trap = ax.contour(R_grid, M_grid, Torque_map_frame,
#                       levels=[0.0], colors='black', linewidths=1.5, linestyles='--')
#
#     ax.set_xscale('log')
#     ax.set_yscale('log')
#     ax.set_xlim(0.1, 210)
#     ax.set_xlabel('Radius [AU]', fontsize=12)
#     ax.set_ylabel(r'Planet Mass [$M_\oplus$]', fontsize=12)
#     ax.set_title(f't = {t_yr/1e6:.2f} Myr | Torque Evolution',
#                  fontsize=13, fontweight='bold')
#
#     cbar = plt.colorbar(cp, ax=ax, ticks=np.arange(-5, 6, 1))
#     cbar.set_label(r'Torque $\Gamma / \Gamma_0$', fontsize=12)
#
#     # Dead zone indicator (if available)
#     if 'rdz' in snapshots:
#         rdz = snapshots['rdz'][snap_idx]
#         ax.axvline(rdz, color='green', linestyle=':', linewidth=2,
#                    label=f'Dead zone edge: {rdz:.1f} AU', alpha=0.7)
#         ax.legend(fontsize=10, loc='upper right')
#
#     plt.tight_layout()
#
#     # Save frame
#     frame_num = f"{snap_idx:04d}"
#     filepath = f'{movie_dir}/frame_{frame_num}.png'
#     plt.savefig(filepath, dpi=100)
#     plt.close()
#
# print(f"✓ Generated {len(torque_maps['t_yr'])} frames in {movie_dir}/")
# print(f"\nTo create a movie with ffmpeg, run:")
# print(f"  ffmpeg -framerate 10 -i {movie_dir}/frame_%04d.png -c:v libx264 -pix_fmt yuv420p output/torque_evolution.mp4")
